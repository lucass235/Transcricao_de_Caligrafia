# %%
# importação dos dados
import os
import tarfile
from tqdm import tqdm
from io import BytesIO
from zipfile import ZipFile
from urllib.request import urlopen

import torch
import torch.optim as optim
from torchsummaryX import summary

from mltu.torch.model import Model
from mltu.torch.losses import CTCLoss
from mltu.torch.dataProvider import DataProvider
from mltu.torch.metrics import CERMetric, WERMetric
from mltu.torch.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, Model2onnx, ReduceLROnPlateau

from mltu.preprocessors import ImageReader
from mltu.transformers import ImageResizer, LabelIndexer, LabelPadding, ImageShowCV2
from mltu.augmentors import RandomBrightness, RandomRotate, RandomErodeDilate, RandomSharpen
from mltu.annotations.images import CVImage

from model import Network
from configs import ModelConfigs

# %% [markdown]
# - Pré processamento dos dados

# %%
dataset, vocab, max_len = [], set(), 0
dataset_path = "../data/iam_data/"
# Processando o dataset pelo formato especifico do dataset IAM_Words
words = open(f"{dataset_path}words.txt", "r").readlines()
for line in tqdm(words):
    if line.startswith("#"):
        continue

    line_split = line.split(" ")
    if line_split[1] == "err":
        continue

    folder1 = line_split[0][:3]
    folder2 = "-".join(line_split[0].split("-")[:2])
    file_name = line_split[0] + ".png"
    label = line_split[-1].rstrip('\n')
    rel_path = f"{dataset_path}words/{folder1}/{folder2}/{file_name}"
    if not os.path.exists(rel_path):
        print(f"File not found: {rel_path}")
        continue

    dataset.append([rel_path, label])
    vocab.update(list(label))
    max_len = max(max_len, len(label))

configs = ModelConfigs()

# Save vocab and maximum text length to configs
configs.vocab = "".join(sorted(vocab))
configs.max_text_length = max_len
configs.save()
# Out:
#   0%|          | 0/115320 [00:00<?, ?it/s]
# 100%|██████████| 115320/115320 [00:05<00:00, 22608.27it/s]

# %%
dataset
# Out:
# [['../data/iam_data/words/a01/a01-000u/a01-000u-00-00.png', 'A'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-00-01.png', 'MOVE'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-00-02.png', 'to'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-00-03.png', 'stop'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-00-04.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-00-05.png', 'Gaitskell'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-00-06.png', 'from'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-01-00.png', 'nominating'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-01-01.png', 'any'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-01-02.png', 'more'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-01-03.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-01-04.png', 'life'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-01-05.png', 'Peers'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-02-00.png', 'is'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-02-01.png', 'to'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-02-02.png', 'be'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-02-03.png', 'made'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-02-04.png', 'at'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-02-05.png', 'a'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-02-06.png', 'meeting'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-02-07.png', 'of'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-02-08.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-04-00.png', 'put'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-04-01.png', 'down'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-04-02.png', 'a'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-04-03.png', 'resolution'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-04-04.png', 'on'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-04-05.png', 'the'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-04-06.png', 'subject'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-06-00.png', 'Griffiths'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-06-01.png', ','],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-06-02.png', 'P'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-06-03.png', 'for'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-06-04.png', 'Manchester'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-06-05.png', 'Exchange'],
#  ['../data/iam_data/words/a01/a01-000u/a01-000u-06-06.png', '.'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-00-00.png', 'A'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-00-01.png', 'MOVE'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-00-02.png', 'to'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-00-03.png', 'stop'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-00-04.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-00-05.png', 'Gaitskell'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-00-06.png', 'from'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-00-07.png', 'nominating'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-01-00.png', 'any'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-01-01.png', 'more'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-01-02.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-01-03.png', 'life'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-01-04.png', 'Peers'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-01-05.png', 'is'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-01-06.png', 'to'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-01-07.png', 'be'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-01-08.png', 'made'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-01-09.png', 'at'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-01-10.png', 'a'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-02-00.png', 'meeting'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-02-01.png', 'of'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-02-02.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-02-03.png', 'Ps'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-02-04.png', 'tomorrow'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-02-05.png', '.'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-02-06.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-02-07.png', 'Michael'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-03-00.png', 'Foot'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-03-01.png', 'has'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-03-02.png', 'put'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-03-03.png', 'down'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-03-04.png', 'a'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-03-05.png', 'resolution'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-03-06.png', 'on'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-03-07.png', 'the'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-03-08.png', 'subject'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-04-00.png', 'and'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-04-01.png', 'he'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-04-02.png', 'is'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-04-03.png', 'to'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-04-04.png', 'be'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-04-05.png', 'backed'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-04-06.png', 'by'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-04-07.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-04-08.png', 'Will'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-04-09.png', 'Griffiths'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-04-10.png', ','],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-05-00.png', 'P'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-05-01.png', 'for'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-05-02.png', 'Manchester'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-05-03.png', 'Exchange'],
#  ['../data/iam_data/words/a01/a01-000x/a01-000x-05-04.png', '.'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-00-00.png', 'Though'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-00-01.png', 'they'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-00-02.png', 'may'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-00-03.png', 'gather'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-00-04.png', 'some'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-00-05.png', 'Left-wing'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-00-06.png', 'support'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-00-07.png', ','],
#  ['../data/iam_data/words/a01/a01-003/a01-003-00-08.png', 'a'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-01-00.png', 'large'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-01-01.png', 'majority'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-01-02.png', 'of'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-01-03.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-01-04.png', 'Ps'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-01-05.png', 'are'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-01-06.png', 'likely'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-01-07.png', 'to'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-02-00.png', 'turn'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-02-01.png', 'down'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-02-02.png', 'the'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-02-03.png', 'Foot-Griffiths'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-02-04.png', 'resolution'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-02-05.png', '.'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-02-06.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-03-00.png', "Foot's"],
#  ['../data/iam_data/words/a01/a01-003/a01-003-03-01.png', 'line'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-03-02.png', 'will'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-03-03.png', 'be'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-03-04.png', 'that'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-03-05.png', 'as'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-03-06.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-03-07.png', 'Ps'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-04-00.png', 'opposed'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-04-01.png', 'the'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-04-02.png', 'Government'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-04-03.png', 'Bill'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-04-04.png', 'which'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-04-05.png', 'brought'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-05-00.png', 'life'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-05-01.png', 'peers'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-05-02.png', 'into'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-05-03.png', 'existence'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-05-04.png', ','],
#  ['../data/iam_data/words/a01/a01-003/a01-003-05-05.png', 'they'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-05-06.png', 'should'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-05-07.png', 'not'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-06-00.png', 'now'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-06-01.png', 'put'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-06-02.png', 'forward'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-06-03.png', 'nominees'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-06-04.png', '.'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-06-05.png', 'He'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-06-06.png', 'believes'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-07-00.png', 'that'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-07-01.png', 'the'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-07-02.png', 'House'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-07-03.png', 'of'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-07-04.png', 'Lords'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-07-05.png', 'should'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-07-06.png', 'be'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-07-07.png', 'abolished'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-08-00.png', 'and'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-08-01.png', 'that'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-08-02.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-08-03.png', 'should'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-08-04.png', 'not'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-08-05.png', 'take'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-08-06.png', 'any'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-08-07.png', 'steps'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-10-00.png', 'institution'],
#  ['../data/iam_data/words/a01/a01-003/a01-003-10-01.png', '.'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-00-00.png', 'Though'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-00-01.png', 'they'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-00-02.png', 'may'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-00-03.png', 'gather'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-00-04.png', 'some'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-00-05.png', 'Left-wing'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-01-00.png', 'support'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-01-01.png', ','],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-01-02.png', 'a'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-01-03.png', 'large'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-01-04.png', 'majority'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-01-05.png', 'of'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-01-06.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-02-00.png', 'Ps'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-02-01.png', 'are'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-02-02.png', 'likely'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-02-03.png', 'to'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-02-04.png', 'turn'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-02-05.png', 'down'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-02-06.png', 'the'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-02-07.png', 'Foot-'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-04-00.png', 'be'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-04-01.png', 'that'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-04-02.png', 'as'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-04-03.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-04-04.png', 'Ps'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-04-05.png', 'opposed'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-04-06.png', 'the'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-05-00.png', 'Government'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-05-01.png', 'Bill'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-05-02.png', 'which'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-05-03.png', 'brought'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-05-04.png', 'life'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-05-05.png', 'peers'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-06-00.png', 'into'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-06-01.png', 'existence'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-06-02.png', ','],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-06-03.png', 'they'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-06-04.png', 'should'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-06-05.png', 'not'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-06-06.png', 'now'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-06-07.png', 'put'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-07-00.png', 'forward'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-07-01.png', 'nominees'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-07-02.png', '.'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-07-03.png', 'He'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-07-04.png', 'believes'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-07-05.png', 'that'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-07-06.png', 'the'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-08-00.png', 'House'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-08-01.png', 'of'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-08-02.png', 'Lords'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-08-03.png', 'should'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-08-04.png', 'be'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-08-05.png', 'abolished'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-08-06.png', 'and'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-09-00.png', 'that'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-09-01.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-09-02.png', 'should'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-09-03.png', 'not'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-09-04.png', 'take'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-09-05.png', 'any'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-09-06.png', 'steps'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-10-00.png', 'which'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-10-01.png', 'would'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-10-02.png', 'appear'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-10-03.png', 'to'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-10-04.png', '"'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-10-05.png', 'prop'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-10-06.png', 'up'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-10-07.png', '"'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-10-08.png', 'an'],
#  ['../data/iam_data/words/a01/a01-003u/a01-003u-10-09.png', 'out-'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-01-00.png', 'large'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-01-01.png', 'majority'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-01-02.png', 'of'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-01-03.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-01-04.png', 'Ps'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-01-05.png', 'are'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-01-06.png', 'likely'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-01-07.png', 'to'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-01-08.png', 'turn'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-04-00.png', 'ment'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-04-01.png', 'Bill'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-04-02.png', 'which'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-04-03.png', 'brought'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-04-04.png', 'life'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-04-05.png', 'peers'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-04-06.png', 'into'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-04-07.png', 'existence'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-04-08.png', ','],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-04-09.png', 'they'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-05-00.png', 'should'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-05-01.png', 'not'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-05-02.png', 'now'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-05-03.png', 'put'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-05-04.png', 'forward'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-05-05.png', 'nominees'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-05-06.png', '.'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-05-07.png', 'He'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-05-08.png', 'believes'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-06-00.png', 'that'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-06-01.png', 'the'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-06-02.png', 'House'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-06-03.png', 'of'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-06-04.png', 'Lords'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-06-05.png', 'should'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-06-06.png', 'be'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-06-07.png', 'abolished'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-06-08.png', 'and'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-07-00.png', 'that'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x-07-01.png', 'Labour'],
#  ['../data/iam_data/words/a01/a01-003x/a01-003x
],
#  ['../data/iam_data/words/a01/a01-011/a01-011-00-00.png', 'Delegates'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-00-01.png', 'from'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-00-02.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-00-03.png', 'Kenneth'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-00-04.png', "Kaunda's"],
#  ['../data/iam_data/words/a01/a01-011/a01-011-00-05.png', 'United'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-00-06.png', 'National'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-00-07.png', 'Independence'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-02-00.png', 'National'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-02-01.png', 'Congress'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-02-02.png', '('],
#  ['../data/iam_data/words/a01/a01-011/a01-011-02-03.png', '400,000'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-02-04.png', ')'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-02-05.png', 'will'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-02-06.png', 'meet'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-02-07.png', 'in'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-02-08.png', 'London'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-02-09.png', 'today'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-03-00.png', 'to'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-03-01.png', 'discuss'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-03-02.png', 'a'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-03-03.png', 'common'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-03-04.png', 'course'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-03-05.png', 'of'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-03-06.png', 'action'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-03-07.png', '.'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-03-08.png', 'Sir'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-03-09.png', 'Roy'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-03-10.png', 'is'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-04-00.png', 'violently'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-04-01.png', 'opposed'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-04-02.png', 'to'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-04-03.png', 'Africans'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-04-04.png', 'getting'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-04-05.png', 'an'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-04-06.png', 'elected'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-04-07.png', 'majority'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-05-00.png', 'in'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-05-01.png', 'Northern'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-05-02.png', 'Rhodesia'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-05-03.png', ','],
#  ['../data/iam_data/words/a01/a01-011/a01-011-05-04.png', 'but'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-05-05.png', 'the'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-05-06.png', 'Colonial'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-05-07.png', 'Secretary'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-05-08.png', ','],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-00.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-01.png', 'Iain'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-02.png', 'Macleod'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-03.png', ','],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-04.png', 'is'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-05.png', 'insisting'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-06.png', 'on'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-07.png', 'a'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-08.png', 'policy'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-09.png', 'of'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-10.png', 'change'],
#  ['../data/iam_data/words/a01/a01-011/a01-011-06-11.png', '.'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-00-00.png', 'Delegates'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-00-01.png', 'from'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-00-02.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-00-03.png', 'Kenneth'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-00-04.png', "Kaunda's"],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-01-00.png', 'United'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-01-01.png', 'National'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-01-02.png', 'Independence'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-01-03.png', 'Party'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-02-00.png', '('],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-02-01.png', '280,000'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-02-02.png', 'members'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-02-03.png', ')'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-02-04.png', 'and'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-02-05.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-02-06.png', 'Harry'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-02-07.png', "Nkumbula's"],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-03-00.png', 'African'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-03-01.png', 'National'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-03-02.png', 'Congress'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-03-03.png', '('],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-03-04.png', '400,000'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-03-05.png', ')'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-03-06.png', 'will'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-04-00.png', 'meet'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-04-01.png', 'in'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-04-02.png', 'London'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-04-03.png', 'today'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-04-04.png', 'to'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-04-05.png', 'discuss'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-04-06.png', 'a'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-04-07.png', 'common'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-05-00.png', 'course'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-05-01.png', 'of'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-05-02.png', 'action'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-05-03.png', '.'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-05-04.png', 'Sir'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-05-05.png', 'Roy'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-05-06.png', 'is'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-05-07.png', 'violently'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-06-00.png', 'opposed'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-06-01.png', 'to'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-06-02.png', 'Africans'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-06-03.png', 'getting'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-06-04.png', 'an'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-06-05.png', 'elected'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-07-00.png', 'majority'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-07-01.png', 'in'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-07-02.png', 'Northern'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-07-03.png', 'Rhodesia'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-07-04.png', ','],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-07-05.png', 'but'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-07-06.png', 'the'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-08-00.png', 'Colonial'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-08-01.png', 'Secretary'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-08-02.png', ','],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-08-03.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-08-04.png', 'Iain'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-08-05.png', 'Macleod'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-08-06.png', ','],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-09-00.png', 'is'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-09-01.png', 'insisting'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-09-02.png', 'on'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-09-03.png', 'a'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-09-04.png', 'policy'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-09-05.png', 'of'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-09-06.png', 'change'],
#  ['../data/iam_data/words/a01/a01-011u/a01-011u-09-07.png', '.'],
#  ['../data/iam_data/words/a01/a01-011x/a01-011x-08-00.png', 'Macleod'],
#  ['../data/iam_data/words/a01/a01-011x/a01-011x-08-01.png', ','],
#  ['../data/iam_data/words/a01/a01-011x/a01-011x-08-02.png', 'is'],
#  ['../data/iam_data/words/a01/a01-011x/a01-011x-08-03.png', 'insisting'],
#  ['../data/iam_data/words/a01/a01-011x/a01-011x-08-04.png', 'on'],
#  ['../data/iam_data/words/a01/a01-011x/a01-011x-08-05.png', 'a'],
#  ['../data/iam_data/words/a01/a01-011x/a01-011x-08-06.png', 'policy'],
#  ['../data/iam_data/words/a01/a01-011x/a01-011x-08-07.png', 'of'],
#  ['../data/iam_data/words/a01/a01-011x/a01-011x-08-08.png', 'change'],
#  ['../data/iam_data/words/a01/a01-011x/a01-011x-08-09.png', '.'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-00-00.png', 'Sir'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-00-01.png', "Roy's"],
#  ['../data/iam_data/words/a01/a01-014/a01-014-00-02.png', 'United'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-00-03.png', 'Federal'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-00-04.png', 'Party'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-00-05.png', 'is'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-00-06.png', 'boycotting'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-01-00.png', 'the'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-01-01.png', 'London'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-01-02.png', 'talks'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-01-03.png', 'on'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-01-04.png', 'the'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-01-05.png', "Protectorate's"],
#  ['../data/iam_data/words/a01/a01-014/a01-014-02-00.png', 'future'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-02-01.png', '.'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-02-02.png', 'Said'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-02-03.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-02-04.png', 'Nkumbula'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-02-05.png', 'last'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-02-06.png', 'night'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-02-07.png', ':'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-03-00.png', '"'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-03-01.png', 'We'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-03-02.png', 'want'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-03-03.png', 'to'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-03-04.png', 'discuss'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-03-05.png', 'what'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-03-06.png', 'to'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-03-07.png', 'do'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-03-08.png', 'if'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-03-09.png', 'the'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-04-00.png', 'British'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-04-01.png', 'Government'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-04-02.png', 'gives'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-04-03.png', 'in'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-04-04.png', 'to'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-04-05.png', 'Sir'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-04-06.png', 'Roy'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-04-07.png', 'and'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-05-00.png', 'the'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-05-01.png', 'talks'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-05-02.png', 'fall'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-05-03.png', 'through'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-05-04.png', '.'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-05-05.png', 'There'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-05-06.png', 'are'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-05-07.png', 'bound'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-07-00.png', 'chief'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-07-01.png', 'aide'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-07-02.png', ','],
#  ['../data/iam_data/words/a01/a01-014/a01-014-07-03.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-07-04.png', 'Julius'],
#  ['../data/iam_data/words/a01/a01-014/a01-014-07-05.png', 'Greenfield'],
#  ['../data/iam_data/words/a01/a01-014/a01-014
],
#  ['../data/iam_data/words/a01/a01-020/a01-020-04-04.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-04-05.png', 'Africans'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-04-06.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-04-07.png', 'overall'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-05-00.png', 'majority'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-05-01.png', 'they'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-05-02.png', 'are'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-05-03.png', 'seeking'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-05-04.png', '.'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-05-05.png', 'African'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-05-06.png', 'delegates'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-06-00.png', 'are'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-06-01.png', 'studying'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-06-02.png', 'them'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-06-03.png', 'today'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-06-04.png', '.'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-06-05.png', 'The'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-06-06.png', 'conference'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-07-00.png', 'will'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-07-01.png', 'meet'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-07-02.png', 'to'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-07-03.png', 'discuss'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-07-04.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-07-05.png', 'function'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-07-06.png', 'of'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-07-07.png', 'a'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-08-00.png', 'proposed'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-08-01.png', 'House'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-08-02.png', 'of'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-08-03.png', 'Chiefs'],
#  ['../data/iam_data/words/a01/a01-020/a01-020-08-04.png', '.'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-00-00.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-00-01.png', 'Macleod'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-00-02.png', 'went'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-00-03.png', 'on'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-00-04.png', 'with'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-00-05.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-00-06.png', 'conference'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-01-00.png', 'at'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-01-01.png', 'Lancaster'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-01-02.png', 'House'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-01-03.png', 'despite'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-01-04.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-01-05.png', 'crisis'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-02-00.png', 'which'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-02-01.png', 'had'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-02-02.png', 'blown'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-02-03.png', 'up'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-02-04.png', '.'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-02-05.png', 'He'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-02-06.png', 'has'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-02-07.png', 'now'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-02-08.png', 'revealed'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-03-00.png', 'his'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-03-01.png', 'full'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-03-02.png', 'plans'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-03-03.png', 'to'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-03-04.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-03-05.png', 'Africans'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-03-06.png', 'and'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-03-07.png', 'Liberals'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-04-00.png', 'attending'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-04-01.png', '.'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-04-02.png', 'These'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-04-03.png', 'plans'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-04-04.png', 'do'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-04-05.png', 'not'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-04-06.png', 'give'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-04-07.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-05-00.png', 'Africans'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-05-01.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-05-02.png', 'overall'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-05-03.png', 'majority'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-05-04.png', 'they'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-05-05.png', 'are'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-06-00.png', 'seeking'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-06-01.png', '.'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-06-02.png', 'African'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-06-03.png', 'delegates'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-06-04.png', 'are'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-06-05.png', 'studying'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-07-00.png', 'them'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-07-01.png', 'today'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-07-02.png', '.'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-07-03.png', 'The'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-07-04.png', 'conference'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-07-05.png', 'will'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-07-06.png', 'meet'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-08-00.png', 'to'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-08-01.png', 'discuss'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-08-02.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-08-03.png', 'function'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-08-04.png', 'of'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-08-05.png', 'a'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-08-06.png', 'proposed'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-09-00.png', 'House'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-09-01.png', 'of'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-09-02.png', 'Chiefs'],
#  ['../data/iam_data/words/a01/a01-020u/a01-020u-09-03.png', '.'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-00-00.png', 'Mr.'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-00-01.png', 'Macleod'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-00-02.png', 'went'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-00-03.png', 'on'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-00-04.png', 'with'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-00-05.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-00-06.png', 'conference'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-00-07.png', 'at'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-01-00.png', 'Lancaster'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-01-01.png', 'House'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-01-02.png', 'despite'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-01-03.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-01-04.png', 'crisis'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-01-05.png', 'which'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-01-06.png', 'had'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-02-00.png', 'blown'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-02-01.png', 'up'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-02-02.png', '.'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-02-03.png', 'He'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-02-04.png', 'has'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-02-05.png', 'now'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-02-06.png', 'revealed'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-02-07.png', 'his'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-02-08.png', 'full'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-02-09.png', 'plans'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-03-00.png', 'to'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-03-01.png', 'the'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-03-02.png', 'Africans'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-03-03.png', 'and'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-03-04.png', 'Liberals'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-03-05.png', 'attending'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-03-06.png', '.'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-03-07.png', 'These'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-04-00.png', 'plans'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-04-01.png', 'do'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-04-02.png', 'not'],
#  ['../data/iam_data/words/a01/a01-020x/a01-020x-04-03.png', 'give'],
#  ...]

# %%
# Criação do modelo e definição dos hiperparâmetros
data_provider = DataProvider(
    dataset=dataset,
    skip_validation=True,
    batch_size=configs.batch_size,
    data_preprocessors=[ImageReader(CVImage)],
    transformers=[
        # ImageShowCV2(),  # uncomment to show images when iterating over the data provider
        ImageResizer(configs.width, configs.height, keep_aspect_ratio=False),
        LabelIndexer(configs.vocab),
        LabelPadding(max_word_length=configs.max_text_length,
                     padding_value=len(configs.vocab))
    ],
    use_cache=True,
)
# Out:
# 2023-06-09 18:18:04,431 INFO DataProvider: Skipping Dataset validation...

# %%
# verificar se o dataset foi carregado corretamente
# for _ in data_provider:
#     pass

# %%
# Divisão do dataset em treino e teste (90% e 10%)
train_dataProvider, test_dataProvider = data_provider.split(split = 0.9)

# %%
#
train_dataProvider.augmentors = [
    RandomBrightness(), 
    RandomErodeDilate(),
    RandomSharpen(),
    RandomRotate(angle=10), 
    ]

# %%
network = Network(len(configs.vocab), activation="leaky_relu", dropout=0.3)
loss = CTCLoss(blank=len(configs.vocab))
optimizer = optim.Adam(network.parameters(), lr=configs.learning_rate)

# %%
# uncomment to print network summary, torchsummaryX package is required
# summary(network, torch.zeros((1, configs.height, configs.width, 3)))

# %%
# Usar GPU
# if torch.cuda.is_available():
#     network = network.cuda()
    
# Usar CPU
os.environ['CUDA_VISIBLE_DEVICES'] = ''
network = network.cpu()

# %%
# Criação do callback para o treinamento
earlyStopping = EarlyStopping(monitor="val_CER", patience=20, mode="min", verbose=1)
modelCheckpoint = ModelCheckpoint(configs.model_path + "/model.pt", monitor="val_CER", mode="min", save_best_only=True, verbose=1)
tb_callback = TensorBoard(configs.model_path + "/logs")
reduce_lr = ReduceLROnPlateau(monitor="val_CER", factor=0.9, patience=10, verbose=1, mode="min", min_lr=1e-6)
model2onnx = Model2onnx(
    saved_model_path=configs.model_path + "/model.pt",
    input_shape=(1, configs.height, configs.width, 3), 
    verbose=1,
    metadata={"vocab": configs.vocab}
    )

# %%
# Criação do modelo para o treinamento
model = Model(network, optimizer, loss, metrics=[CERMetric(configs.vocab), WERMetric(configs.vocab)])
model.fit(
    train_dataProvider, 
    test_dataProvider, 
    epochs=7, 
    callbacks=[earlyStopping, modelCheckpoint, tb_callback, reduce_lr, Model2onnx(
        saved_model_path=configs.model_path + "/model.pt",
        input_shape=(1, configs.height, configs.width, 3), 
        verbose=1,
        metadata={"vocab": configs.vocab},
        onnx_opset_version=10
    )]
)
# Out:
# Epoch 1 - loss: 4.7632 - CER: 1.0349 - WER: 1.0000:  30%|███       | 409/1357 [04:37<10:33,  1.50it/s] 2023-06-09 18:22:45,202 WARNING ImageReader: Image ../data/iam_data/words/r06/r06-022/r06-022-03-05.png could not be read, returning None.
# 2023-06-09 18:22:45,209 WARNING DataProvider: Data or annotation is None, marking for removal on epoch end.
# Epoch 1 - loss: 3.5033 - CER: 0.9370 - WER: 0.9369:  94%|█████████▍| 1279/1357 [14:35<00:52,  1.48it/s]2023-06-09 18:32:42,678 WARNING ImageReader: Image ../data/iam_data/words/a01/a01-117/a01-117-05-02.png could not be read, returning None.
# 2023-06-09 18:32:42,681 WARNING DataProvider: Data or annotation is None, marking for removal on epoch end.
# Epoch 1 - loss: 3.4491 - CER: 0.9289 - WER: 0.9303: 100%|██████████| 1357/1357 [15:28<00:00,  1.46it/s]
# 2023-06-09 18:33:35,773 WARNING DataProvider: Removing ['../data/iam_data/words/r06/r06-022/r06-022-03-05.png', 'more'] from dataset.
# 2023-06-09 18:33:35,784 WARNING DataProvider: Removing ['../data/iam_data/words/a01/a01-117/a01-117-05-02.png', 'Powell'] from dataset.
#           val_loss: 2.4098 - val_CER: 0.7661 - val_WER: 0.7958: 100%|██████████| 151/151 [00:42<00:00,  3.59it/s]
# 2023-06-09 18:34:17,859 INFO ModelCheckpoint: Epoch 1: val_CER improved from inf to 0.76605, saving model to Models/08_handwriting_recognition_torch\202306091818/model.pt
# Epoch 2 - loss: 2.2792 - CER: 0.7230 - WER: 0.7780: 100%|██████████| 1357/1357 [13:59<00:00,  1.62it/s]
#           val_loss: 2.6696 - val_CER: 0.7615 - val_WER: 0.8263: 100%|██████████| 151/151 [00:26<00:00,  5.66it/s]
# 2023-06-09 18:48:43,900 INFO ModelCheckpoint: Epoch 2: val_CER improved from 0.76605 to 0.76149, saving model to Models/08_handwriting_recognition_torch\202306091818/model.pt
# Epoch 3 - loss: 1.9402 - CER: 0.6504 - WER: 0.7239: 100%|██████████| 1357/1357 [14:01<00:00,  1.61it/s]
#           val_loss: 1.6388 - val_CER: 0.5870 - val_WER: 0.6774: 100%|██████████| 151/151 [00:29<00:00,  5.04it/s]
# 2023-06-09 19:03:15,246 INFO ModelCheckpoint: Epoch 3: val_CER improved from 0.76149 to 0.58702, saving model to Models/08_handwriting_recognition_torch\202306091818/model.pt
# Epoch 4 - loss: 1.7062 - CER: 0.5901 - WER: 0.6819: 100%|██████████| 1357/1357 [14:05<00:00,  1.61it/s]
#           val_loss: 1.4095 - val_CER: 0.5101 - val_WER: 0.6212: 100%|██████████| 151/151 [00:29<00:00,  5.18it/s]
# 2023-06-09 19:17:49,773 INFO ModelCheckpoint: Epoch 4: val_CER improved from 0.58702 to 0.51008, saving model to Models/08_handwriting_recognition_torch\202306091818/model.pt
# Epoch 5 - loss: 1.5256 - CER: 0.5361 - WER: 0.6436: 100%|██████████| 1357/1357 [14:02<00:00,  1.61it/s]
#           val_loss: 1.4974 - val_CER: 0.5076 - val_WER: 0.6398: 100%|██████████| 151/151 [00:28<00:00,  5.24it/s]
# 2023-06-09 19:32:21,518 INFO ModelCheckpoint: Epoch 5: val_CER improved from 0.51008 to 0.50765, saving model to Models/08_handwriting_recognition_torch\202306091818/model.pt
# Epoch 6 - loss: 1.3901 - CER: 0.4959 - WER: 0.6168: 100%|██████████| 1357/1357 [14:04<00:00,  1.61it/s]
#           val_loss: 1.0942 - val_CER: 0.4132 - val_WER: 0.5486: 100%|██████████| 151/151 [00:28<00:00,  5.32it/s]
# 2023-06-09 19:46:54,429 INFO ModelCheckpoint: Epoch 6: val_CER improved from 0.50765 to 0.41319, saving model to Models/08_handwriting_recognition_torch\202306091818/model.pt
# Epoch 7 - loss: 1.2876 - CER: 0.4659 - WER: 0.5972: 100%|██████████| 1357/1357 [14:22<00:00,  1.57it/s]
#           val_loss: 1.0370 - val_CER: 0.3884 - val_WER: 0.5347: 100%|██████████| 151/151 [00:28<00:00,  5.33it/s]
# 2023-06-09 20:01:45,394 INFO ModelCheckpoint: Epoch 7: val_CER improved from 0.41319 to 0.38842, saving model to Models/08_handwriting_recognition_torch\202306091818/model.pt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\lucas\Documents\GitHub\Transcricao_de_Caligrafia\handwriting_recognition_torch\train.ipynb Cell 13 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # Criação do modelo para o treinamento
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> model = Model(network, optimizer, loss, metrics=[CERMetric(configs.vocab), WERMetric(configs.vocab)])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> model.fit(
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>     train_dataProvider,
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>     test_dataProvider,
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>     epochs=7,
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>     callbacks=[earlyStopping, modelCheckpoint, tb_callback, reduce_lr, Model2onnx(
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a>         saved_model_path=configs.model_path + "/model.pt",
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a>         input_shape=(1, configs.height, configs.width, 3),
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a>         verbose=1,
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a>         metadata={"vocab": configs.vocab}
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=11'>12</a>     )]
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a> )
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python38\lib\site-packages\mltu\torch\model.py:255, in Model.fit(self, train_dataProvider, test_dataProvider, epochs, initial_epoch, callbacks)
#     251         break
#     253     self._epoch += 1
# --> 255 self.callbacks.on_train_end(logs)
#     257 return logs
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python38\lib\site-packages\mltu\torch\handlers.py:66, in CallbacksHandler.on_train_end(self, logs)
#      64 def on_train_end(self, logs=None):
#      65     for callback in self.callbacks:
# ---> 66         callback.on_train_end(logs)
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python38\lib\site-packages\mltu\torch\callbacks.py:309, in Model2onnx.on_train_end(self, logs)
#     306 dummy_input = torch.randn(self.input_shape)
#     308 # Export the model
# --> 309 torch.onnx.export(
#     310     self.model.model,
#     311     dummy_input,
#     312     self.onnx_model_path,
#     313     export_params=self.export_params,
#     314     opset_version=self.opset_version,
#     315     do_constant_folding=self.do_constant_folding,
#     316     input_names = self.input_names,
#     317     output_names = self.output_names,
#     318     dynamic_axes = self.dynamic_axes,
#     319     )
#     321 if self.verbose:
#     322     self.logger.info(f"Model saved to {self.onnx_model_path}")
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python38\lib\site-packages\torch\onnx\__init__.py:275, in export(model, args, f, export_params, verbose, training, input_names, output_names, aten, export_raw_ir, operator_export_type, opset_version, _retain_param_name, do_constant_folding, example_outputs, strip_doc_string, dynamic_axes, keep_initializers_as_inputs, custom_opsets, enable_onnx_checker, use_external_data_format)
#      38 r"""
#      39 Export a model into ONNX format.  This exporter runs your model
#      40 once in order to get a trace of its execution to be exported;
#    (...)
#     271         than ONNX.
#     272 """
#     274 from torch.onnx import utils
# --> 275 return utils.export(model, args, f, export_params, verbose, training,
#     276                     input_names, output_names, aten, export_raw_ir,
#     277                     operator_export_type, opset_version, _retain_param_name,
#     278                     do_constant_folding, example_outputs,
#     279                     strip_doc_string, dynamic_axes, keep_initializers_as_inputs,
#     280                     custom_opsets, enable_onnx_checker, use_external_data_format)
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python38\lib\site-packages\torch\onnx\utils.py:88, in export(model, args, f, export_params, verbose, training, input_names, output_names, aten, export_raw_ir, operator_export_type, opset_version, _retain_param_name, do_constant_folding, example_outputs, strip_doc_string, dynamic_axes, keep_initializers_as_inputs, custom_opsets, enable_onnx_checker, use_external_data_format)
#      86     else:
#      87         operator_export_type = OperatorExportTypes.ONNX
# ---> 88 _export(model, args, f, export_params, verbose, training, input_names, output_names,
#      89         operator_export_type=operator_export_type, opset_version=opset_version,
#      90         _retain_param_name=_retain_param_name, do_constant_folding=do_constant_folding,
#      91         example_outputs=example_outputs, strip_doc_string=strip_doc_string,
#      92         dynamic_axes=dynamic_axes, keep_initializers_as_inputs=keep_initializers_as_inputs,
#      93         custom_opsets=custom_opsets, enable_onnx_checker=enable_onnx_checker,
#      94         use_external_data_format=use_external_data_format)
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python38\lib\site-packages\torch\onnx\utils.py:672, in _export(model, args, f, export_params, verbose, training, input_names, output_names, operator_export_type, export_type, example_outputs, opset_version, _retain_param_name, do_constant_folding, strip_doc_string, dynamic_axes, keep_initializers_as_inputs, fixed_batch_size, custom_opsets, add_node_names, enable_onnx_checker, use_external_data_format, onnx_shape_inference)
#     664         operator_export_type = OperatorExportTypes.ONNX
#     666 # By default, training=None, (which defaults to TrainingMode.EVAL),
#     667 # which is good because running a model in training mode could result in
#     668 # internal buffers getting updated, dropout getting applied, etc.
#     669 # If you really know what you're doing, you can turn
#     670 # training=TrainingMode.TRAINING or training=TrainingMode.PRESERVE,
#     671 # (to preserve whatever the original training mode was.)
# --> 672 _set_opset_version(opset_version)
#     673 _set_operator_export_type(operator_export_type)
#     674 with select_model_mode_for_export(model, training):
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python38\lib\site-packages\torch\onnx\symbolic_helper.py:783, in _set_opset_version(opset_version)
#     781     _export_onnx_opset_version = opset_version
#     782     return
# --> 783 raise ValueError("Unsupported ONNX opset version: " + str(opset_version))
#
# ValueError: Unsupported ONNX opset version: 14

# %%
# salvar o modelo
model.save(configs.model_path + "/model.hdf5")

# %%
# Save training and validation datasets as csv files
train_dataProvider.to_csv(os.path.join("./", "train.csv"))
test_dataProvider.to_csv(os.path.join("./", "val.csv"))

# %%
# testar com uma imagem
import cv2
import numpy as np
from keras.models import load_model

# Carrega o modelo treinado
model = load_model(configs.model_path + "/model.hdf5")

# Carrega a imagem
image = cv2.imread("../data/iam_data/words/a01/a01-000u/a01-000u-00-00.png")

# Pré-processa a imagem
image = cv2.resize(image, (configs.image_size, configs.image_size))
image = image.astype("float") / 255.0
image = np.expand_dims(image, axis=0)

# Faz a previsão na imagem
prediction = model.predict(image)

# Imprime a previsão
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\lucas\Documents\GitHub\Transcricao_de_Caligrafia\handwriting_recognition_torch\train.ipynb Cell 16 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> from keras.models import load_model
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> # Carrega o modelo treinado
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a> model = load_model(configs.model_path + "/model.hdf5")
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a> # Carrega a imagem
#      <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/GitHub/Transcricao_de_Caligrafia/handwriting_recognition_torch/train.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> image = cv2.imread("../data/iam_data/words/a01/a01-000u/a01-000u-00-00.png")
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\saving\saving_api.py:212, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     204     return saving_lib.load_model(
#     205         filepath,
#     206         custom_objects=custom_objects,
#     207         compile=compile,
#     208         safe_mode=safe_mode,
#     209     )
#     211 # Legacy case.
# --> 212 return legacy_sm_saving_lib.load_model(
#     213     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214 )
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python38\lib\site-packages\h5py\_hl\files.py:567, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     558     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     559                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     560                      alignment_threshold=alignment_threshold,
#     561                      alignment_interval=alignment_interval,
#     562                      meta_block_size=meta_block_size,
#     563                      **kwds)
#     564     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     565                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                      fs_page_size=fs_page_size)
# --> 567     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     569 if isinstance(libver, tuple):
#     570     self._libver = libver
#
# File c:\Users\lucas\AppData\Local\Programs\Python\Python38\lib\site-packages\h5py\_hl\files.py:231, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229     if swmr and swmr_support:
#     230         flags |= h5f.ACC_SWMR_READ
# --> 231     fid = h5f.open(name, flags, fapl=fapl)
#     232 elif mode == 'r+':
#     233     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\h5f.pyx:106, in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)
